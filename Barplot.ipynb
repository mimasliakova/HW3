# %% [markdown]
# ## Barplot, HW3

# %% [markdown]
# Импорт необходимых библиотек

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %% [markdown]
# Создание массивов данных

# %%
labels = ['Sudan', 'Myanmar', 'Ethiopia', 'Brazil', 'Argentina',
          'Colombia', 'Pakistan', 'Bangladesh', 'Viet Nam', 'Nigeria',
          'India', 'Thailand', 'Indonesia',
          'Australia', 'Mexico', 'China', 'Europian Union(28)',
          'United States', 'Canada', 'Russia', 'Average Rest of the World']
values = np.array([82, 70, 60, 45, 44, 44, 40, 40, 32, 30, 24, 22, 20, 17,
                   13, 11, 10, 8, 8, 7, 30]) 
values
#массивы данных для первого barplot
# Out:
# array([82, 70, 60, 45, 44, 44, 40, 40, 32, 30, 24, 22, 20, 17, 13, 11, 10,
#         8,  8,  7, 30])

# %%
europe = ['Ireland', 'Lithuania', 'Latvia', 'France', 'Denmark', 'Romania',
          'Hungary', 'Croatia', 'Sweden', 'Portugal', 'Spain', 'Malta',
          'Bulgaria', 'Slovenia', 'Austria', 'Cyprus', 'Finland', 'Poland',
          'United Kingdom', 'Belgium', 'Greece', 'Netherlands', 'Estonia',
          'Germany', 'Italy', 'Slovakia', 'Czech Republic', 'Luxembourg',
          'European Union(28)']
e_values = np.array([30, 23, 22, 18, 17, 15, 14, 13, 13, 11, 11, 10, 10, 9,
                    9, 9, 8.5, 8.5, 8, 8, 8, 7.5, 7.5, 7, 7, 5.5, 5.5, 3, 10])
e_values
#массивы данных для второго barplot
# Out:
# array([30. , 23. , 22. , 18. , 17. , 15. , 14. , 13. , 13. , 11. , 11. ,
#        10. , 10. ,  9. ,  9. ,  9. ,  8.5,  8.5,  8. ,  8. ,  8. ,  7.5,
#         7.5,  7. ,  7. ,  5.5,  5.5,  3. , 10. ])

# %% [markdown]
# Построение barplot

# %%
#порядок цветов для bars в barplot
colors = ['orange', 'orange', 'orange', 'orange', 'orange',
          'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
          'orange', 'orange', 'orange', 'orange', 'orange', 'royalblue',
          'orange', 'orange', 'orange', 'grey']
e_colors = ['skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue',
            'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue',
            'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue',
            'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue',
            'skyblue', 'skyblue', 'skyblue', 'skyblue', 'skyblue', 'royalblue']
index = np.arange(len(labels))
e_index = np.arange(len(europe))
#ось x в процентах
formatter = FuncFormatter(lambda x, pos: "%d%%" % (x))
#создание barplot
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot(1, 2, 1)  #2 barplot'а рядом
ax1.barh(index, values, height=0.5, color=colors)
#названия на оси y
ax1.set_yticks(index)
ax1.set_yticklabels(labels, fontsize=8)
ax1.set_title("Agricultire's share in total national GHG emissions",
              fontsize=14)  #название barplot
ax1 = plt.gca()
ax1.xaxis.set_major_formatter(formatter)
ax1.grid(axis='x')  #разделение методом grid
ax1.spines['right'].set_visible(False)  #удаление ненужных границ
ax1.spines['top'].set_visible(False)
#для пресечения наложение barplot друг на друга
plt.tight_layout()

#построение второго barplot рядом с первым
ax2 = plt.subplot(1, 2, 2)
ax2.barh(e_index, e_values, height=0.5, color=e_colors)
ax2.set_yticks(e_index)
ax2.set_yticklabels(europe, fontsize=8)
ax2.set_title("Agricultire's share in total national GHG emissions in\n"
              "the EU Member States",
              fontsize=14)
ax2 = plt.gca()
ax2.xaxis.set_major_formatter(formatter)
ax2.grid(axis='x')
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
plt.tight_layout()
